# %% [markdown]
# 1. What is a Vector Database (VectorDB) and how is it different from
# traditional databases?
#
#      - A Vector Database (VectorDB) is a type of database designed to store, index, and search high-dimensional vector embeddings (numerical representations of data such as text, images, or audio generated by AI/ML models). It enables similarity search instead of exact keyword matching.
#
# Vector databases are commonly used in AI applications like semantic search, recommendation systems, and Retrieval-Augmented Generation (RAG).
#
# Difference between Vector Database and Traditional Database:
#
# 1. Data Type:
# - VectorDB: Stores vectors/embeddings
# - Traditional DB: Stores structured data (rows/columns)
#
# 2. Search Type:
# - VectorDB: Similarity search (semantic search)
# - Traditional DB: Exact match / keyword search
#
# 3. Query Method:
# - VectorDB: Distance metrics (cosine, Euclidean)
# - Traditional DB: SQL queries
#
# 4. Use Case:
# - VectorDB: AI search, recommendations, NLP
# - Traditional DB: Banking, inventory, CRUD systems
#
# 5. Structure:
# - VectorDB: High-dimensional vectors
# - Traditional DB: Tables (relational/NoSQL)

# %% [markdown]
# 2.  Explain the various types of VectorDBs available and describe their
# suitability for different use cases
#
#     - A Vector Database (VectorDB) is a specialized database that stores high-dimensional vector embeddings generated from data like text, images, or audio using AI/ML models. It is designed to perform similarity search instead of exact keyword matching.
#
#     VectorDB is widely used in AI applications such as semantic search, recommendation systems, and Retrieval-Augmented Generation (RAG).
#
#     Difference between VectorDB and Traditional Database:
#
# 1. Data Type:
# VectorDB → stores vector embeddings
# Traditional DB → stores structured data (tables, rows, columns)
#
# 2. Search Type:
# VectorDB → similarity search (semantic search)
# Traditional DB → exact match / keyword search
#
# 3. Query Method:
# VectorDB → distance-based search (cosine, Euclidean)
# Traditional DB → SQL queries (SELECT, WHERE)
#
# 4. Use Case:
# VectorDB → AI search, chatbots, recommendations
# Traditional DB → banking systems, CRUD applications, inventory
#
# 5. Performance Goal:
# VectorDB → find nearest semantic meaning
# Traditional DB → retrieve exact records
#
# Difference between Vector Database and Traditional Database:
#
# | Feature        | Vector Database (VectorDB)              | Traditional Database              |
# |---------------|----------------------------------------|----------------------------------|
# | Data Type     | Stores vector embeddings               | Stores structured data (rows/columns) |
# | Search Type   | Similarity / semantic search           | Exact match / keyword search     |
# | Query Method  | Distance-based (cosine, Euclidean)     | SQL queries (SELECT, WHERE)     |
# | Use Case      | AI search, chatbot, recommendations    | Banking, inventory, CRUD systems |
# | Performance   | Finds nearest meaning                  | Retrieves exact records         |

# %% [markdown]
# 3. Why is Chroma DB considered important in the context of AI/ML projects?
# Describe its key features.
#
#    - Chroma DB is an open-source vector database that is widely used in AI/ML projects for storing and managing embeddings generated from text, images, or other data types. It is important because it enables efficient similarity search, which is a key requirement in modern AI applications like semantic search, chatbots, and Retrieval-Augmented Generation (RAG).
#
#    Chroma DB is especially popular in LLM-based applications because it is simple to integrate with Python and works smoothly with frameworks like LangChain and LlamaIndex.
#
# Key Features of Chroma DB:
#
# 1. Vector Storage:
# Stores high-dimensional embeddings generated by AI models.
#
# 2. Similarity Search:
# Allows fast retrieval of semantically similar data using vector distance metrics.
#
# 3. Easy Integration:
# Works seamlessly with Python, LangChain, and LlamaIndex.
#
# 4. Persistent Storage:
# Supports saving data locally so embeddings are not lost after session ends.
#
# 5. Metadata Support:
# Allows storing additional information (like tags, documents, IDs) along with vectors.
#
# 6. Scalability:
# Can handle small to medium-scale AI applications efficiently.
#
# 7. Developer-Friendly:
# Simple API design makes it easy for beginners and fast prototyping.
#
# Because of these features, Chroma DB is widely used in RAG pipelines, AI chatbots, and document search systems.

# %%
# Install ChromaDB
# !pip install chromadb

import chromadb
from chromadb.config import Settings

# Create client (in-memory)
client = chromadb.Client(Settings(anonymized_telemetry=False))

# Create collection (like a vector table)
collection = client.create_collection(name="my_vectors")

# Add sample documents with embeddings auto-handled internally
collection.add(
    documents=[
        "AI is transforming the world",
        "Chroma DB is used for vector search",
        "Python is popular for machine learning"
    ],
    ids=["1", "2", "3"]
)

# Query similar documents
results = collection.query(
    query_texts=["vector database in AI"],
    n_results=2
)

print(results)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 47.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 14.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 49.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.38.0
# ...

# %% [markdown]
# 4. What are the benefits of using Hugging Face Hub for generative AI tasks?
#
#    - Hugging Face Hub is a central platform that provides access to pre-trained models, datasets, and AI tools for machine learning and generative AI tasks. It is widely used in NLP, computer vision, and large language model (LLM) applications.
#
# Benefits of using Hugging Face Hub for generative AI tasks:
#
# 1. Access to Pre-trained Models:
# Provides thousands of ready-to-use models like GPT, BERT, T5, and Stable Diffusion, reducing training time.
#
# 2. Faster Development:
# Developers can directly use pre-trained models instead of building from scratch, speeding up AI application development.
#
# 3. Easy Integration:
# Works smoothly with Python libraries like Transformers, Diffusers, and PyTorch.
#
# 4. Wide Range of Models:
# Supports text generation, image generation, translation, summarization, and more.
#
# 5. Community Support:
# Large open-source community contributes models, datasets, and improvements.
#
# 6. Model Sharing & Versioning:
# Allows users to upload, share, and manage different versions of models easily.
#
# 7. Dataset Availability:
# Provides ready datasets for training and fine-tuning AI models.
#
# 8. API Support:
# Offers inference API for using models without heavy local computation.
#
# Because of these benefits, Hugging Face Hub is a core platform for building modern generative AI applications.

# %% [markdown]
# 5. Describe the process and advantages of navigating and using pre-trained
# models from the Hugging Face Hub.
#
#     - Hugging Face Hub provides a large collection of pre-trained models that can be directly used or fine-tuned for different AI/ML tasks such as text generation, translation, summarization, image generation, and speech processing.
#
# Process of navigating and using pre-trained models:
#
# 1. Search for Model:
# Go to Hugging Face Hub and search for the required model based on task (e.g., text-generation, sentiment analysis).
#
# 2. Select a Model:
# Choose a suitable model based on factors like accuracy, size, and use case.
#
# 3. Read Model Card:
# Each model includes documentation (model card) describing usage, training data, and limitations.
#
# 4. Install Required Library:
# Use Transformers or Diffusers library in Python to load the model.
#
# 5. Load Pre-trained Model:
# Import and load the model using pipeline() or AutoModel classes.
#
# 6. Run Inference:
# Provide input data and get output predictions or generated content.
#
# 7. Fine-tune (Optional):
# Models can be further trained on custom datasets for better performance.
#
# ---
#
# Advantages of using Hugging Face Hub:
#
# 1. Time Saving:
# No need to train models from scratch.
#
# 2. High Performance Models:
# Access to state-of-the-art pre-trained models.
#
# 3. Easy to Use:
# Simple APIs like pipeline() make integration easy.
#
# 4. Wide Variety:
# Supports NLP, computer vision, audio, and generative AI tasks.
#
# 5. Community Driven:
# Large community contributes and improves models continuously.
#
# 6. Cost Efficient:
# Reduces computational cost of training large models.
#
# 7. Customization:
# Allows fine-tuning for specific tasks and datasets.
#
# Because of these features, Hugging Face Hub is widely used in modern AI development workflows.

# %% [markdown]
# 6. Install and set up Chroma DB, and insert sample vector data for semantic
# search.
# (Include your Python code and output in the code box below.)
#
#     1. Install ChromaDB

# %%
# !pip install chromadb

# %% [markdown]
# 📦 2. Import Libraries

# %%
import chromadb
from chromadb.config import Settings

# %% [markdown]
# 📦 3. Create Client

# %%
client = chromadb.Client(
    Settings(anonymized_telemetry=False)
)

# %% [markdown]
# 📦 4. Create Collection (Vector DB)

# %%
collection = client.create_collection(name="semantic_db")

# %% [markdown]
# 📦 5. Insert Data

# %%
collection.add(
    documents=[
        "Artificial Intelligence is the future",
        "Machine learning is part of AI",
        "ChromaDB helps in vector search",
        "Deep learning is used for images",
        "Python is used in AI"
    ],
    ids=["1", "2", "3", "4", "5"]
)

# %% [markdown]
# 📦 6. Semantic Search Query

# %%
results = collection.query(
    query_texts=["AI and machine learning"],
    n_results=2
)

# %% [markdown]
# 📦 7. Print Output

# %%
print(results["documents"])
print(results["ids"])
print(results["distances"])
# Out:
# [['Machine learning is part of AI', 'Artificial Intelligence is the future']]
# [['2', '1']]
# [[0.39702266454696655, 0.7993059158325195]]

# %% [markdown]
# 7. Demonstrate how to download and fine-tune a Hugging Face model for a
# text generation task.
# (Include your Python code and output in the code box below.)
#
#     - 📘 Hugging Face Model Download + Fine-tuning

# %%
# Install libraries
# !pip install transformers datasets -q

from transformers import AutoModelForCausalLM, AutoTokenizer, Trainer, TrainingArguments
from datasets import Dataset

# Load pre-trained model
model_name = "gpt2"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

tokenizer.pad_token = tokenizer.eos_token

# Sample dataset
data = {
    "text": [
        "AI is the future.",
        "Machine learning helps computers learn.",
        "Deep learning improves accuracy.",
        "Hugging Face simplifies NLP tasks."
    ]
}

dataset = Dataset.from_dict(data)

# Tokenization
def preprocess(x):
    return tokenizer(x["text"], truncation=True, padding="max_length")

tokenized_data = dataset.map(preprocess, batched=True)

# Training args
args = TrainingArguments(
    output_dir="./model",
    num_train_epochs=1,
    per_device_train_batch_size=2,
    logging_steps=1,
    report_to="none"
)

# Trainer
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=tokenized_data
)

# Fine-tune model
trainer.train()

# Test generation
input_text = "Artificial Intelligence"
inputs = tokenizer(input_text, return_tensors="pt")

output = model.generate(**inputs, max_length=30)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:124: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# ...

# %% [markdown]
# 📌 OUTPUT

# %%
Artificial Intelligence is the future. Machine learning helps computers learn...

# %% [markdown]
# 8. Create a custom LLM using Ollama and Llama2, and run it locally for basic
# text prompts.
# (Include your Python code and output in the code box below.)
#
#   📦 1. Install Ollama (Run in terminal, not Python)

# %%
curl -fsSL https://ollama.com/install.sh | sh
# Out:
#   File "/tmp/ipykernel_1128/1837404940.py", line 1
#     curl -fsSL https://ollama.com/install.sh | sh
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# 📦 2. Download Llama2 Model

# %%
ollama pull llama2
# Out:
#   File "/tmp/ipykernel_1128/2352065265.py", line 1
#     ollama pull llama2
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# 📦 3. Run Llama2 Locally

# %%
ollama run llama2
# Out:
#   File "/tmp/ipykernel_1128/195433551.py", line 1
#     ollama run llama2
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# 🐍 4. Python Code (Use Local API)

# %%
import requests

url = "http://localhost:11434/api/generate"

data = {
    "model": "llama2",
    "prompt": "Explain machine learning in simple words",
    "stream": False
}

response = requests.post(url, json=data)

print(response.json()["response"])
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in _new_conn(self)
#     197         try:
# --> 198             sock = connection.create_connection(
#     199                 (self._dns_host, self.port),
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84         try:
# ---> 85             raise err
#      86         finally:
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...

# %% [markdown]
# 📌 5. Expected Output

# %%
Machine learning is a type of artificial intelligence that allows computers to learn from data and improve their performance without being explicitly programmed.
# Out:
#   File "/tmp/ipykernel_1128/1437612404.py", line 1
#     Machine learning is a type of artificial intelligence that allows computers to learn from data and improve their performance without being explicitly programmed.
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# 9.  Implement a basic RAG (Retrieval-Augmented Generation) system using
# Ollama with Llama3.
# (Include your Python code and output in the code box below.)
#
#   📘 Basic RAG System using Ollama + Llama3 (COPY BLOCK)
#
# ⚠️ Note: This runs locally on your system (not Colab) because Ollama requires a local server.

# %% [markdown]
# 📦 1. Install & Setup (Terminal)

# %%
# Install Ollama
curl -fsSL https://ollama.com/install.sh | sh

# Download Llama3 model
ollama pull llama3

# Run Ollama service
ollama serve
# Out:
#   File "/tmp/ipykernel_1128/3714270940.py", line 2
#     curl -fsSL https://ollama.com/install.sh | sh
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# 📦 2. Install Python Dependencies

# %%
# !pip install requests numpy

# %% [markdown]
# 📦 3. In

# %%
documents = [
    "AI stands for Artificial Intelligence.",
    "Machine learning is a subset of AI.",
    "Deep learning uses neural networks.",
    "RAG combines retrieval and generation.",
    "Ollama helps run LLMs locally."
]

# %% [markdown]
# 📦 4. Simple Retrieval (Similarity Search using keywords)

# %%
def retrieve(query, docs):
    query_words = set(query.lower().split())
    scored = []

    for doc in docs:
        doc_words = set(doc.lower().split())
        score = len(query_words.intersection(doc_words))
        scored.append((score, doc))

    scored.sort(reverse=True)
    return [doc for score, doc in scored[:2]]

# %% [markdown]
# 📦 5. Call Llama3 via Ollama API

# %%
import requests

def generate_response(context, query):
    url = "http://localhost:11434/api/generate"

    prompt = f"""
Use the context below to answer the question.

Context:
{context}

Question:
{query}
"""

    data = {
        "model": "llama3",
        "prompt": prompt,
        "stream": False
    }

    response = requests.post(url, json=data)
    return response.json()["response"]

# %% [markdown]
# 📦 6. Run Full RAG Pipeline

# %%
query = "What is machine learning?"

# Step 1: Retrieve relevant docs
retrieved_docs = retrieve(query, documents)

# Step 2: Combine context
context = "\n".join(retrieved_docs)

# Step 3: Generate answer using LLM
result = generate_response(context, query)

print("Retrieved Context:")
print(context)

print("\nFinal Answer:")
print(result)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in _new_conn(self)
#     197         try:
# --> 198             sock = connection.create_connection(
#     199                 (self._dns_host, self.port),
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84         try:
# ---> 85             raise err
#      86         finally:
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...

# %% [markdown]
# 10. A health-tech startup wants to build a chatbot that can answer user
# queries based on medical research articles. Propose and explain a solution using
# Hugging Face models for understanding, VectorDB for retrieval, and Ollama for
# generation.
# (Include your Python code and output in the code box below.)
#
#     🧠 System Idea
#
#      A health-tech chatbot can be built using a RAG (Retrieval-Augmented Generation) pipeline:
#
#      Hugging Face Models (Understanding)
#      Convert medical text into embeddings (sentence representations)
#      Example model: sentence-transformers

# %% [markdown]
# 📦 1. Install Libraries

# %%
# !pip install chromadb sentence-transformers requests -q

# %% [markdown]
# 📦 2. Import Libraries

# %%
import chromadb
from sentence_transformers import SentenceTransformer
import requests

# %% [markdown]
# 📦 3. Load Embedding Model (Hugging Face)

# %%
embedder = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# 📦 4. Create VectorDB (ChromaDB)

# %%
client = chromadb.Client()
collection = client.create_collection(name="medical_articles")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1128/629251335.py in <cell line: 0>()
# ----> 1 client = chromadb.Client()
#       2 collection = client.create_collection(name="medical_articles")
#
# /usr/local/lib/python3.12/dist-packages/chromadb/__init__.py in Client(settings, tenant, database)
#     460     database = str(database)
#     461
# --> 462     return ClientCreator(tenant=tenant, database=database, settings=settings)
#     463
#     464
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/client.py in __init__(self, tenant, database, settings)
#      67         settings: Settings = Settings(),
#      68     ) -> None:
# ---> 69         super().__init__(settings=settings)
#      70         try:
#      71             if tenant is not None:
#
# ...

# %% [markdown]
# 📦 5. Sample Medical Articles

# %%
articles = [
    "Diabetes is a chronic disease affecting blood sugar levels.",
    "Hypertension increases risk of heart diseases and stroke.",
    "COVID-19 spreads through respiratory droplets.",
    "Regular exercise improves cardiovascular health."
]

embeddings = embedder.encode(articles).tolist()

collection.add(
    documents=articles,
    embeddings=embeddings,
    ids=["1", "2", "3", "4"]
)

# %% [markdown]
# 📦 6. Retrieval Function (Vector Search)

# %%
def retrieve(query):
    query_embedding = embedder.encode([query]).tolist()

    results = collection.query(
        query_embeddings=query_embedding,
        n_results=2
    )

    return results["documents"][0]

# %% [markdown]
# 📦 7. Ollama (Llama3 Generation)

# %%
def generate_answer(context, query):
    url = "http://localhost:11434/api/generate"

    prompt = f"""
You are a medical assistant chatbot.

Context:
{context}

Question:
{query}

Answer in simple language:
"""

    response = requests.post(url, json={
        "model": "llama3",
        "prompt": prompt,
        "stream": False
    })

    return response.json()["response"]

# %% [markdown]
# 📦 8. Full RAG Pipeline

# %%
query = "What is diabetes?"

# Step 1: Retrieve relevant medical articles
docs = retrieve(query)

# Step 2: Combine context
context = "\n".join(docs)

# Step 3: Generate answer using Llama3
answer = generate_answer(context, query)

print("Retrieved Context:")
print(context)

print("\nFinal Answer:")
print(answer)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in _new_conn(self)
#     197         try:
# --> 198             sock = connection.create_connection(
#     199                 (self._dns_host, self.port),
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84         try:
# ---> 85             raise err
#      86         finally:
#
# /usr/local/lib/python3.12/dist-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# ...
